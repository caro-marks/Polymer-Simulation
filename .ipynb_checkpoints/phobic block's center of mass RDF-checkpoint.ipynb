# %%
import pandas as pd
import numpy as np
import os
# from matplotlib import pyplot as plt
# import seaborn; seaborn.set()

# %%
Beads_range=[x for x in range(10,50,4) if x not in (38,46)]
Frac_range=[x/100 for x in range(0,100,25) if x!=0]
Dens_range=[x/100 for x in range(0,81,5) if x>0]
polymers = 1000

# %%
def Data(file, frac, bead):    
    n_pho = int(bead*abs(frac-1))
    n_phi = bead-n_pho
    data = pd.read_table(file, sep='\s+', header = 1)
    X = pd.Series([round(data['x'][part:part+bead].mean(),5) for part in range(0,bead*polymers,bead)])
    Y = pd.Series([round(data['y'][part:part+bead].mean(),5) for part in range(0,bead*polymers,bead)])
    Z = pd.Series([round(data['z'][part:part+bead].mean(),5) for part in range(0,bead*polymers,bead)])
    X0 = pd.Series([round(data.loc[data.type == 0, 'x'][part:part+n_phi].mean(),5) for part in range(0,n_phi*polymers,n_phi)])
    Y0 = pd.Series([round(data.loc[data.type == 0, 'y'][part:part+n_phi].mean(),5) for part in range(0,n_phi*polymers,n_phi)])
    Z0 = pd.Series([round(data.loc[data.type == 0, 'z'][part:part+n_phi].mean(),5) for part in range(0,n_phi*polymers,n_phi)])
    X1 = pd.Series([round(data.loc[data.type == 1, 'x'][part:part+n_pho].mean(),5) for part in range(0,n_pho*polymers,n_pho)])
    Y1 = pd.Series([round(data.loc[data.type == 1, 'y'][part:part+n_pho].mean(),5) for part in range(0,n_pho*polymers,n_pho)])
    Z1 = pd.Series([round(data.loc[data.type == 1, 'z'][part:part+n_pho].mean(),5) for part in range(0,n_pho*polymers,n_pho)])
    return X, Y, Z, X0, Y0, Z0, X1, Y1, Z1

# %%
def prepend_line(file_name, line):    
    dummy_file = file_name + '.bak'
    
    with open(file_name, 'r') as read_obj, open(dummy_file, 'w') as write_obj:
        write_obj.write(str(line) + '\n')
        for line in read_obj:
            write_obj.write(line)
            
    os.remove(file_name)
    os.rename(dummy_file, file_name)

# %%
def RDFer(Beads, Fracs, Denss):
    
    for Bead in Beads:
            
            for Frac in Fracs:
                
                frac = int((1-Frac)*10%10)
                
                for Dens in Denss:      
                    
                    File = 'frac_'+str(Frac)+'/m_'+str(Bead)+'/d_'+str(Dens)+'/final_snapshot.xyz'
                    
                    x, y, z, x0, y0, z0, x1, y1, z1 = Data(File, Frac, Bead)
                    
                    CM = pd.DataFrame({'Type':2, 'X_cm':x, 'Y_cm':y, 'Z_cm':z})
                    CM0 = pd.DataFrame({'Type':0, 'X_cm':x0, 'Y_cm':y0, 'Z_cm':z0})
                    CM1 = pd.DataFrame({'Type':1, 'X_cm':x1, 'Y_cm':y1, 'Z_cm':z1})
                    
                    file = 'centros_de_massas/chain_cm/f_'+str(frac)+'-b_'+str(Bead)+'-d_'+str(Dens)+'.xyz'
                    file0 = 'centros_de_massas/blocos_filicos/f_'+str(frac)+'-b_'+str(Bead)+'-d_'+str(Dens)+'.xyz'                        
                    file1 = 'centros_de_massas/blocos_fobicos/f_'+str(frac)+'-b_'+str(Bead)+'-d_'+str(Dens)+'.xyz'
                    
                    CM.to_csv(file, index=None, sep=',', mode='w')
                    CM0.to_csv(file0, index=None, sep=',', mode='w')
                    CM1.to_csv(file1, index=None, sep=',', mode='w')
                    
                    prepend_line(file, polymers)
                    prepend_line(file0, polymers)
                    prepend_line(file1, polymers)
                    
                    print(Bead, Frac, Dens,'thank you, next')

# %%
RDFer(Beads_range,Frac_range,Dens_range)
# Out:
# 10 0.25 0.05 thank you, next
# 10 0.25 0.1 thank you, next
# 10 0.25 0.15 thank you, next
# 10 0.25 0.2 thank you, next
# 10 0.25 0.25 thank you, next
# 10 0.25 0.3 thank you, next
# 10 0.25 0.35 thank you, next
# 10 0.25 0.4 thank you, next
# 10 0.25 0.45 thank you, next
# 10 0.25 0.5 thank you, next
# 10 0.25 0.55 thank you, next
# 10 0.25 0.6 thank you, next
# 10 0.25 0.65 thank you, next
# 10 0.25 0.7 thank you, next
# 10 0.25 0.75 thank you, next
# 10 0.25 0.8 thank you, next
# 10 0.5 0.05 thank you, next
# 10 0.5 0.1 thank you, next
# 10 0.5 0.15 thank you, next
# 10 0.5 0.2 thank you, next
# 10 0.5 0.25 thank you, next
# 10 0.5 0.3 thank you, next
# 10 0.5 0.35 thank you, next
# 10 0.5 0.4 thank you, next
# 10 0.5 0.45 thank you, next
# 10 0.5 0.5 thank you, next
# 10 0.5 0.55 thank you, next
# 10 0.5 0.6 thank you, next
# 10 0.5 0.65 thank you, next
# 10 0.5 0.7 thank you, next
# 10 0.5 0.75 thank you, next
# 10 0.5 0.8 thank you, next
# 10 0.75 0.05 thank you, next
# 10 0.75 0.1 thank you, next
# 10 0.75 0.15 thank you, next
# 10 0.75 0.2 thank you, next
# 10 0.75 0.25 thank you, next
# 10 0.75 0.3 thank you, next
# 10 0.75 0.35 thank you, next
# 10 0.75 0.4 thank you, next
# 10 0.75 0.45 thank you, next
# 10 0.75 0.5 thank you, next
# 10 0.75 0.55 thank you, next
# 10 0.75 0.6 thank you, next
# 10 0.75 0.65 thank you, next
# 10 0.75 0.7 thank you, next
# 10 0.75 0.75 thank you, next
# 10 0.75 0.8 thank you, next
# 14 0.25 0.05 thank you, next
# 14 0.25 0.1 thank you, next
# 14 0.25 0.15 thank you, next
# 14 0.25 0.2 thank you, next
# 14 0.25 0.25 thank you, next
# 14 0.25 0.3 thank you, next
# 14 0.25 0.35 thank you, next
# 14 0.25 0.4 thank you, next
# 14 0.25 0.45 thank you, next
# 14 0.25 0.5 thank you, next
# 14 0.25 0.55 thank you, next
# 14 0.25 0.6 thank you, next
# 14 0.25 0.65 thank you, next
# 14 0.25 0.7 thank you, next
# 14 0.25 0.75 thank you, next
# 14 0.25 0.8 thank you, next
# 14 0.5 0.05 thank you, next
# 14 0.5 0.1 thank you, next
# 14 0.5 0.15 thank you, next
# 14 0.5 0.2 thank you, next
# 14 0.5 0.25 thank you, next
# 14 0.5 0.3 thank you, next
# 14 0.5 0.35 thank you, next
# 14 0.5 0.4 thank you, next
# 14 0.5 0.45 thank you, next
# 14 0.5 0.5 thank you, next
# 14 0.5 0.55 thank you, next
# 14 0.5 0.6 thank you, next
# 14 0.5 0.65 thank you, next
# 14 0.5 0.7 thank you, next
# 14 0.5 0.75 thank you, next
# 14 0.5 0.8 thank you, next
# 14 0.75 0.05 thank you, next
# 14 0.75 0.1 thank you, next
# 14 0.75 0.15 thank you, next
# 14 0.75 0.2 thank you, next
# 14 0.75 0.25 thank you, next
# 14 0.75 0.3 thank you, next
# 14 0.75 0.35 thank you, next
# 14 0.75 0.4 thank you, next
# 14 0.75 0.45 thank you, next
# 14 0.75 0.5 thank you, next
# 14 0.75 0.55 thank you, next
# 14 0.75 0.6 thank you, next
# 14 0.75 0.65 thank you, next
# 14 0.75 0.7 thank you, next
# 14 0.75 0.75 thank you, next
# 14 0.75 0.8 thank you, next
# 18 0.25 0.05 thank you, next
# 18 0.25 0.1 thank you, next
# 18 0.25 0.15 thank you, next
# 18 0.25 0.2 thank you, next
# 18 0.25 0.25 thank you, next
# 18 0.25 0.3 thank you, next
# 18 0.25 0.35 thank you, next
# 18 0.25 0.4 thank you, next
# 18 0.25 0.45 thank you, next
# 18 0.25 0.5 thank you, next
# 18 0.25 0.55 thank you, next
# 18 0.25 0.6 thank you, next
# 18 0.25 0.65 thank you, next
# 18 0.25 0.7 thank you, next
# 18 0.25 0.75 thank you, next
# 18 0.25 0.8 thank you, next
# 18 0.5 0.05 thank you, next
# 18 0.5 0.1 thank you, next
# 18 0.5 0.15 thank you, next
# 18 0.5 0.2 thank you, next
# 18 0.5 0.25 thank you, next
# 18 0.5 0.3 thank you, next
# 18 0.5 0.35 thank you, next
# 18 0.5 0.4 thank you, next
# 18 0.5 0.45 thank you, next
# 18 0.5 0.5 thank you, next
# 18 0.5 0.55 thank you, next
# 18 0.5 0.6 thank you, next
# 18 0.5 0.65 thank you, next
# 18 0.5 0.7 thank you, next
# 18 0.5 0.75 thank you, next
# 18 0.5 0.8 thank you, next
# 18 0.75 0.05 thank you, next
# 18 0.75 0.1 thank you, next
# 18 0.75 0.15 thank you, next
# 18 0.75 0.2 thank you, next
# 18 0.75 0.25 thank you, next
# 18 0.75 0.3 thank you, next
# 18 0.75 0.35 thank you, next
# 18 0.75 0.4 thank you, next
# 18 0.75 0.45 thank you, next
# 18 0.75 0.5 thank you, next
# 18 0.75 0.55 thank you, next
# 18 0.75 0.6 thank you, next
# 18 0.75 0.65 thank you, next
# 18 0.75 0.7 thank you, next
# 18 0.75 0.75 thank you, next
# 18 0.75 0.8 thank you, next
# 22 0.25 0.05 thank you, next
# 22 0.25 0.1 thank you, next
# 22 0.25 0.15 thank you, next
# 22 0.25 0.2 thank you, next
# 22 0.25 0.25 thank you, next
# 22 0.25 0.3 thank you, next
# 22 0.25 0.35 thank you, next
# 22 0.25 0.4 thank you, next
# 22 0.25 0.45 thank you, next
# 22 0.25 0.5 thank you, next
# 22 0.25 0.55 thank you, next
# 22 0.25 0.6 thank you, next
# 22 0.25 0.65 thank you, next
# 22 0.25 0.7 thank you, next
# 22 0.25 0.75 thank you, next
# 22 0.25 0.8 thank you, next
# 22 0.5 0.05 thank you, next
# 22 0.5 0.1 thank you, next
# 22 0.5 0.15 thank you, next
# 22 0.5 0.2 thank you, next
# 22 0.5 0.25 thank you, next
# 22 0.5 0.3 thank you, next
# 22 0.5 0.35 thank you, next
# 22 0.5 0.4 thank you, next
# 22 0.5 0.45 thank you, next
# 22 0.5 0.5 thank you, next
# 22 0.5 0.55 thank you, next
# 22 0.5 0.6 thank you, next
# 22 0.5 0.65 thank you, next
# 22 0.5 0.7 thank you, next
# 22 0.5 0.75 thank you, next
# 22 0.5 0.8 thank you, next
# 22 0.75 0.05 thank you, next
# 22 0.75 0.1 thank you, next
# 22 0.75 0.15 thank you, next
# 22 0.75 0.2 thank you, next
# 22 0.75 0.25 thank you, next
# 22 0.75 0.3 thank you, next
# 22 0.75 0.35 thank you, next
# 22 0.75 0.4 thank you, next
# 22 0.75 0.45 thank you, next
# 22 0.75 0.5 thank you, next
# 22 0.75 0.55 thank you, next
# 22 0.75 0.6 thank you, next
# 22 0.75 0.65 thank you, next
# 22 0.75 0.7 thank you, next
# 22 0.75 0.75 thank you, next
# 22 0.75 0.8 thank you, next
# 26 0.25 0.05 thank you, next
# 26 0.25 0.1 thank you, next
# 26 0.25 0.15 thank you, next
# 26 0.25 0.2 thank you, next
# 26 0.25 0.25 thank you, next
# 26 0.25 0.3 thank you, next
# 26 0.25 0.35 thank you, next
# 26 0.25 0.4 thank you, next
# 26 0.25 0.45 thank you, next
# 26 0.25 0.5 thank you, next
# 26 0.25 0.55 thank you, next
# 26 0.25 0.6 thank you, next
# 26 0.25 0.65 thank you, next
# 26 0.25 0.7 thank you, next
# 26 0.25 0.75 thank you, next
# 26 0.25 0.8 thank you, next
# 26 0.5 0.05 thank you, next
# 26 0.5 0.1 thank you, next
# 26 0.5 0.15 thank you, next
# 26 0.5 0.2 thank you, next
# 26 0.5 0.25 thank you, next
# 26 0.5 0.3 thank you, next
# 26 0.5 0.35 thank you, next
# 26 0.5 0.4 thank you, next
# 26 0.5 0.45 thank you, next
# 26 0.5 0.5 thank you, next
# 26 0.5 0.55 thank you, next
# 26 0.5 0.6 thank you, next
# 26 0.5 0.65 thank you, next
# 26 0.5 0.7 thank you, next
# 26 0.5 0.75 thank you, next
# 26 0.5 0.8 thank you, next
# 26 0.75 0.05 thank you, next
# 26 0.75 0.1 thank you, next
# 26 0.75 0.15 thank you, next
# 26 0.75 0.2 thank you, next
# 26 0.75 0.25 thank you, next
# 26 0.75 0.3 thank you, next
# 26 0.75 0.35 thank you, next
# 26 0.75 0.4 thank you, next
# 26 0.75 0.45 thank you, next
# 26 0.75 0.5 thank you, next
# 26 0.75 0.55 thank you, next
# 26 0.75 0.6 thank you, next
# 26 0.75 0.65 thank you, next
# 26 0.75 0.7 thank you, next
# 26 0.75 0.75 thank you, next
# 26 0.75 0.8 thank you, next
# 30 0.25 0.05 thank you, next
# 30 0.25 0.1 thank you, next
# 30 0.25 0.15 thank you, next
# 30 0.25 0.2 thank you, next
# 30 0.25 0.25 thank you, next
# 30 0.25 0.3 thank you, next
# 30 0.25 0.35 thank you, next
# 30 0.25 0.4 thank you, next
# 30 0.25 0.45 thank you, next
# 30 0.25 0.5 thank you, next
# 30 0.25 0.55 thank you, next
# 30 0.25 0.6 thank you, next
# 30 0.25 0.65 thank you, next
# 30 0.25 0.7 thank you, next
# 30 0.25 0.75 thank you, next
# 30 0.25 0.8 thank you, next
# 30 0.5 0.05 thank you, next
# 30 0.5 0.1 thank you, next
# 30 0.5 0.15 thank you, next
# 30 0.5 0.2 thank you, next
# 30 0.5 0.25 thank you, next
# 30 0.5 0.3 thank you, next
# 30 0.5 0.35 thank you, next
# 30 0.5 0.4 thank you, next
# 30 0.5 0.45 thank you, next
# 30 0.5 0.5 thank you, next
# 30 0.5 0.55 thank you, next
# 30 0.5 0.6 thank you, next
# 30 0.5 0.65 thank you, next
# 30 0.5 0.7 thank you, next
# 30 0.5 0.75 thank you, next
# 30 0.5 0.8 thank you, next
# 30 0.75 0.05 thank you, next
# 30 0.75 0.1 thank you, next
# 30 0.75 0.15 thank you, next
# 30 0.75 0.2 thank you, next
# 30 0.75 0.25 thank you, next
# 30 0.75 0.3 thank you, next
# 30 0.75 0.35 thank you, next
# 30 0.75 0.4 thank you, next
# 30 0.75 0.45 thank you, next
# 30 0.75 0.5 thank you, next
# 30 0.75 0.55 thank you, next
# 30 0.75 0.6 thank you, next
# 30 0.75 0.65 thank you, next
# 30 0.75 0.7 thank you, next
# 30 0.75 0.75 thank you, next
# 30 0.75 0.8 thank you, next
# 34 0.25 0.05 thank you, next
# 34 0.25 0.1 thank you, next
# 34 0.25 0.15 thank you, next
# 34 0.25 0.2 thank you, next
# 34 0.25 0.25 thank you, next
# 34 0.25 0.3 thank you, next
# 34 0.25 0.35 thank you, next
# 34 0.25 0.4 thank you, next
# 34 0.25 0.45 thank you, next
# 34 0.25 0.5 thank you, next
# 34 0.25 0.55 thank you, next
# 34 0.25 0.6 thank you, next
# 34 0.25 0.65 thank you, next
# 34 0.25 0.7 thank you, next
# 34 0.25 0.75 thank you, next
# 34 0.25 0.8 thank you, next
# 34 0.5 0.05 thank you, next
# 34 0.5 0.1 thank you, next
# 34 0.5 0.15 thank you, next
# 34 0.5 0.2 thank you, next
# 34 0.5 0.25 thank you, next
# 34 0.5 0.3 thank you, next
# 34 0.5 0.35 thank you, next
# 34 0.5 0.4 thank you, next
# 34 0.5 0.45 thank you, next
# 34 0.5 0.5 thank you, next
# 34 0.5 0.55 thank you, next
# 34 0.5 0.6 thank you, next
# 34 0.5 0.65 thank you, next
# 34 0.5 0.7 thank you, next
# 34 0.5 0.75 thank you, next
# 34 0.5 0.8 thank you, next
# 34 0.75 0.05 thank you, next
# 34 0.75 0.1 thank you, next
# 34 0.75 0.15 thank you, next
# 34 0.75 0.2 thank you, next
# 34 0.75 0.25 thank you, next
# 34 0.75 0.3 thank you, next
# 34 0.75 0.35 thank you, next
# 34 0.75 0.4 thank you, next
# 34 0.75 0.45 thank you, next
# 34 0.75 0.5 thank you, next
# 34 0.75 0.55 thank you, next
# 34 0.75 0.6 thank you, next
# 34 0.75 0.65 thank you, next
# 34 0.75 0.7 thank you, next
# 34 0.75 0.75 thank you, next
# 34 0.75 0.8 thank you, next
# 42 0.25 0.05 thank you, next
# 42 0.25 0.1 thank you, next
# 42 0.25 0.15 thank you, next
# 42 0.25 0.2 thank you, next
# 42 0.25 0.25 thank you, next
# 42 0.25 0.3 thank you, next
# 42 0.25 0.35 thank you, next
# 42 0.25 0.4 thank you, next
# 42 0.25 0.45 thank you, next
# 42 0.25 0.5 thank you, next
# 42 0.25 0.55 thank you, next
# 42 0.25 0.6 thank you, next
# 42 0.25 0.65 thank you, next
# 42 0.25 0.7 thank you, next
# 42 0.25 0.75 thank you, next
# 42 0.25 0.8 thank you, next
# 42 0.5 0.05 thank you, next
# 42 0.5 0.1 thank you, next
# 42 0.5 0.15 thank you, next
# 42 0.5 0.2 thank you, next
# 42 0.5 0.25 thank you, next
# 42 0.5 0.3 thank you, next
# 42 0.5 0.35 thank you, next
# 42 0.5 0.4 thank you, next
# 42 0.5 0.45 thank you, next
# 42 0.5 0.5 thank you, next
# 42 0.5 0.55 thank you, next
# 42 0.5 0.6 thank you, next
# 42 0.5 0.65 thank you, next
# 42 0.5 0.7 thank you, next
# 42 0.5 0.75 thank you, next
# 42 0.5 0.8 thank you, next
# 42 0.75 0.05 thank you, next
# 42 0.75 0.1 thank you, next
# 42 0.75 0.15 thank you, next
# 42 0.75 0.2 thank you, next
# 42 0.75 0.25 thank you, next
# 42 0.75 0.3 thank you, next
# 42 0.75 0.35 thank you, next
# 42 0.75 0.4 thank you, next
# 42 0.75 0.45 thank you, next
# 42 0.75 0.5 thank you, next
# 42 0.75 0.55 thank you, next
# 42 0.75 0.6 thank you, next
# 42 0.75 0.65 thank you, next
# 42 0.75 0.7 thank you, next
# 42 0.75 0.75 thank you, next
# 42 0.75 0.8 thank you, next
